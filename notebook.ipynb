# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/relevant_columns.csv')

# %%
df.max()
# Out:
# age                        94.0
# sex                           M
# bmi                        43.2
# department              Urology
# intraop_ebl             30100.0
# surgery_duration          955.0
# anes_duration            1860.0
# ane_type                 Spinal
# asa                         4.0
# approach            Videoscopic
# los_postop           222.951493
# icu_days                    179
# death_inhosp                  1
# mortality_label        Survived
# color                       red
# avg_hr               140.051128
# dtype: object

# %%
df[(df['age'] == 80) & (df['sex'] == 'F')]
# Out:
#        age sex   bmi        department  intraop_ebl  surgery_duration  \
# 135   80.0   F  30.9   General surgery        100.0         65.000000
# 385   80.0   F  27.0   General surgery        150.0         33.000000
# 443   80.0   F  20.0   General surgery        550.0        175.000000
# 501   80.0   F  24.9   General surgery        150.0         45.000000
# 2300  80.0   F  23.9   General surgery        150.0        198.333333
# 2536  80.0   F  31.5   General surgery        150.0        105.000000
# 2652  80.0   F  18.1   General surgery         50.0        105.000000
# 2663  80.0   F  22.2   General surgery        150.0         50.000000
# 2860  80.0   F  25.9   General surgery        500.0        140.000000
# 3256  80.0   F  19.8   General surgery        150.0         75.000000
# 3742  80.0   F  25.3   General surgery        150.0         85.000000
# 3964  80.0   F  25.5           Urology        150.0         10.000000
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'department', 'intraop_ebl', 'surgery_duration',
#        'anes_duration', 'ane_type', 'asa', 'approach', 'los_postop',
#        'icu_days', 'death_inhosp', 'mortality_label', 'color', 'avg_hr'],
#       dtype='object')
