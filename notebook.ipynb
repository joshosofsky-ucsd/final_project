# %%
import numpy as np
import pandas as pd

# %%
pd.read_csv('data/relevant_columns.csv')['los_postop'].mean()
# Out:
#        age sex   bmi       department  intraop_ebl  surgery_duration  \
# 0     77.0   M  26.3  General surgery        150.0             145.0
# 1     54.0   M  19.6  General surgery         50.0             215.0
# 2     62.0   M  24.4  General surgery        150.0              32.0
# 3     74.0   M  20.5  General surgery        150.0             255.0
# 4     66.0   M  20.4  General surgery       2600.0             295.0
# ...    ...  ..   ...              ...          ...               ...
# 6236  64.0   M  24.2  General surgery        100.0             200.0
# 6237  69.0   M  24.6  General surgery        100.0             285.0
# 6238  61.0   F  18.8  General surgery        100.0             245.0
# 6239  24.0   F  22.9  General surgery        150.0             155.0
# 6240  47.0   F  22.9       Gynecology        150.0             115.0
#
#       anes_duration ane_type  asa     approach  los_postop  death_inhosp  \
# ...
